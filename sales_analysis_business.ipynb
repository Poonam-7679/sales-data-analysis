# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from data folder
df = pd.read_csv("../data/sales_data_enhanced.csv")
df['Date'] = pd.to_datetime(df['Date'])

print("✅ Data loaded successfully!")
print(f"Total records: {len(df)}")
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("data/sales_data_enhanced.csv")
df['Date'] = pd.to_datetime(df['Date'])

print("✅ Data loaded successfully!")
print(f"Total records: {len(df)}")
df.head()
